# %%
# ! pip install openai

# %%
# ! which pip

# %%
import pandas as pd
from glob import glob
import os
import openai
from tqdm import tqdm
from statistics import mean
import warnings

tqdm.pandas()

PATH = "/home/nikolay/wspace/AutoTMDatasets/MARKUP/archive/TOLOKA_Markup"

# %%
dfs = [pd.read_csv(fpath, sep='\t') for fpath in glob(os.path.join(PATH, "*.tsv"))]
df = pd.concat(dfs)

# %%
df['INPUT:model_id'].unique().shape
# Out:
# (405,)

# %%
df[['INPUT:model_id', 'INPUT:topic_id']].drop_duplicates().shape
# Out:
# (6715, 2)

# %%
df.columns
# Out:
# Index(['INPUT:exp_id', 'INPUT:wordset', 'INPUT:model_id', 'INPUT:topic_id',
#        'INPUT:dataset_name', 'INPUT:correct_bad_words', 'OUTPUT:quality',
#        'OUTPUT:bad_words', 'OUTPUT:topic_name', 'OUTPUT:golden_bad_words',
#        'OUTPUT:golden_binary_quality', 'GOLDEN:quality', 'GOLDEN:bad_words',
#        'GOLDEN:topic_name', 'GOLDEN:golden_bad_words',
#        'GOLDEN:golden_binary_quality', 'HINT:text', 'HINT:default_language',
#        'ASSIGNMENT:link', 'ASSIGNMENT:task_id', 'ASSIGNMENT:assignment_id',
#        'ASSIGNMENT:task_suite_id', 'ASSIGNMENT:worker_id', 'ASSIGNMENT:status',
#        'ASSIGNMENT:started', 'ASSIGNMENT:submitted', 'ASSIGNMENT:accepted',
#        'ASSIGNMENT:rejected', 'ASSIGNMENT:skipped', 'ASSIGNMENT:expired',
#        'ASSIGNMENT:reward'],
#       dtype='object')

# %%
tdf = df[['INPUT:dataset_name', 'INPUT:model_id', 'INPUT:topic_id', 'INPUT:wordset', 'OUTPUT:quality', 'OUTPUT:topic_name', 'OUTPUT:bad_words']]

# %%
tdf['OUTPUT:quality'].unique()
# Out:
# array(['good', nan, 'bad', 'rather_bad', 'rather_good'], dtype=object)

# %%
tdf['OUTPUT:quality'].hist()
# Out:
# <Axes: >

# %%
SAMPLES_COUNT = 5
sample_tdf = tdf.groupby(['INPUT:dataset_name', 'OUTPUT:quality'], group_keys=False).apply(lambda x: x.sample(min(len(x), 2)))

# %%
sample_tdf
# Out:
#      INPUT:dataset_name            INPUT:model_id INPUT:topic_id  \
# 4240       20newsgroups  631b96a72b337b5d9500c778         main47
# 6272       20newsgroups  631bb4fb174d83c12d0f4ee3         main69
# 2471       20newsgroups  631b8a9b17dc5fce149d08a8         main23
# 1601       20newsgroups  631b919eb9644773b836b884         main22
# 5528       20newsgroups  631babf6e8f8f2cd1cfaddbb         main54
# 319        20newsgroups  631bb75e9bf9fbe525bc5630         main29
# 794        20newsgroups  631b96bea5a57837b841b5d1          main1
# 3288       20newsgroups  631b963d60e7802f72e1ded0         main69
# 4252        amazon_food  632308451b24cf3ff7176832          main3
# 1373        amazon_food  63230ee8c4040a0e0e0c401e         main22
# 3427        amazon_food  63230f63a6fa8975eb57cf9e         main81
# 2573        amazon_food  6323199e035ec213a22ea493          main1
# 3731        amazon_food  632310c625d962cdec4c13db         main31
# 9203        amazon_food  63261d6acc7373c8fe435e38         main37
# 5257        amazon_food  6315dcee7712429874817fb5         main40
# 8255        amazon_food  632310c625d962cdec4c13db         main43
# 1241           lenta_ru  631b8ee3b0950bb2e7891434         main37
# 361            lenta_ru  62f9cc119da9c4a19ccafffd        unknown
# 1790           lenta_ru  631b869e7668936a8be4f75a          main7
# 2053           lenta_ru  631b8c69814e124a8fb05aed         main99
# 2662           lenta_ru  631b88ec8f66b70aae934dcb         main21
# 108            lenta_ru  62f8a789a028a6a053a5998f        unknown
# 798            lenta_ru  62f7f8458e75b646479de4f7        unknown
# 7725           lenta_ru  631b8aee2b337b5d9500b9ca         main78
#
#                                           INPUT:wordset OUTPUT:quality  \
# 4240  entry launch remark rule satellite european bu...            bad
# 6272  engineer newspaper holland chapter staff dougl...            bad
# 2471  religion atheist belief religious atheism fait...           good
# 1601  population bullet arab israeli border village ...           good
# 5528  unix directory comp package library email linu...     rather_bad
# 319   woman building city left child home face helme...     rather_bad
# 794   attack lebanese muslim hernlem israeli left tr...    rather_good
# 3288  science holland cult compass study tempest inv...    rather_good
# 4252  coconut tell difference cannot benefit along t...            bad
# 1373  pretty especially often set mind point instant...            bad
# 3427  review see disappointed reviewer call similar ...           good
# 2573  back wonderful new home change next amaze issu...           good
# 3731  year old save soup ago awesome subscribe stock...     rather_bad
# 9203  can't almond ounce blue wait cocoa magnesium c...     rather_bad
# 5257  odor effective kill gel lose mask skin acne ca...    rather_good
# 8255  strong prefer people bold orange ginger medium...    rather_good
# 1241  создавать мужчина премьер добавлять причина ос...            bad
# 361   победа россиянин чемпион американец ассоциация...            bad
# 1790  взрыв больница смерть инцидент тело ранение об...           good
# 2053  оборона истребитель вооружение вертолет индия ...           good
# 2662  виктор язык юрий иран статус ющенко иранский л...     rather_bad
# 108   строительство проект площадь построить участок...     rather_bad
# 798   животное церковь килограмм штат собака парк пт...    rather_good
# 7725  устройство разрабатывать обеспечение использов...    rather_good
#
#              OUTPUT:topic_name  \
# 4240                       NaN
# 6272                       NaN
# 2471                 Religion
# 1601             Slaughtering
# 5528                       NaN
# 319                        NaN
# 794      War between countries
# 3288             Investigation
# 4252                       NaN
# 1373                       NaN
# 3427                  Reporter
# 2573                   Moving
# 3731                       NaN
# 9203                       NaN
# 5257                      Acne
# 8255                     Shake
# 1241                       NaN
# 361                        NaN
# 1790                    Теракт
# 2053                     война
# 2662                       NaN
# 108                        NaN
# 798   помощь местному зоопарку
# 7725                   Гаджеты
#
#                                        OUTPUT:bad_words
# 4240  {"entry":false,"launch":false,"remark":false,"...
# 6272  {"princeton":false,"nixon":false,"senior":fals...
# 2471  {"religion":false,"atheist":false,"belief":fal...
# 1601  {"population":false,"bullet":false,"arab":fals...
# 5528  {"unix":false,"directory":false,"comp":false,"...
# 319   {"woman":false,"building":false,"city":false,"...
# 794   {"attack":false,"lebanese":false,"muslim":fals...
# 3288  {"science":false,"holland":false,"cult":false,...
# 4252  {"coconut":false,"tell":false,"difference":fal...
# 1373  {"pretty":false,"especially":false,"often":fal...
# 3427  {"review":false,"see":false,"disappointed":fal...
# 2573  {"back":false,"wonderful":false,"new":false,"h...
# 3731  {"year":false,"old":false,"save":false,"soup":...
# 9203  {"can't":false,"almond":false,"ounce":false,"b...
# 5257  {"odor":true,"effective":false,"kill":false,"g...
# 8255  {"strong":false,"prefer":false,"people":false,...
# 1241  {"создавать":false,"мужчина":false,"премьер":f...
# 361   {"победа":false,"россиянин":false,"чемпион":fa...
# 1790  {"обнаруживать":false,"взрыв":false,"тело":fal...
# 2053  {"оборона":false,"истребитель":false,"вооружен...
# 2662  {"виктор":false,"язык":false,"юрий":false,"ира...
# 108   {"строительство":false,"проект":false,"площадь...
# 798   {"животное":false,"церковь":true,"килограмм":f...
# 7725  {"устройство":false,"разрабатывать":false,"обе...

# %%
sample_tdf[sample_tdf['INPUT:dataset_name'] == 'lenta_ru']['INPUT:wordset'].tolist()
# Out:
# ['создавать мужчина премьер добавлять причина оставаться клуб александр сергей закон идти комитет безопасность национальный предлагать',
#  'победа россиянин чемпион американец ассоциация встречаться завершаться килограмм побеждать карьера поражение состояться всемирный категория боец одерживать поединок суметь соперник проигрывать',
#  'взрыв больница смерть инцидент тело ранение обнаруживать пострадать состояние убивать убийство скончаться пострадавший мужчина теракт',
#  'оборона истребитель вооружение вертолет индия боевой комплекс министерство ракета машина учение индийский ракетный километр минобороны',
#  'виктор язык юрий иран статус ющенко иранский лужков тегеран янукович ядерный русский государственный политика водка',
#  'строительство проект площадь построить участок торговый объект метр планироваться парк центр отель комплекс общий петербург мост оцениваться ресторан гостиница располагаться',
#  'животное церковь килограмм штат собака парк птица хозяин священник святой обнаруживать православный жить находить медведь телевизор внимание помогать местный зоопарк',
#  'устройство разрабатывать обеспечение использоваться технология телефон мобильный разрешение сегодня компьютер карта apple смартфон одновременно приложение']

# %%
def evaluate_by_llm():
    for model_name, dataset_model in dataset.items():
				print (dataset_name, model_name)
				topics = dataset_model["topics"]
				human_evaluations = dataset_model["metrics"]["ratings_scores_avg"]
				i = 0
				for topic, human_eval in tqdm(zip(topics, human_evaluations), total=50):
					topic = topic[:10]
					for run in range(3):
						random.shuffle(topic)
						user_prompt = ", ".join(topic)
						if dataset_name == "wikitext":
							system_prompt = system_prompt_wikitext
						else:
							system_prompt = system_prompt_NYT
						response = openai.ChatCompletion.create(model="gpt-3.5-turbo", messages = [{"role": "system", "content": system_prompt}, {"role": "user", "content": user_prompt}], temperature=1.0, logit_bias={16:100, 17:100, 18:100}, max_tokens=1)["choices"][0]["message"]["content"].strip()
						out = {"dataset_name": dataset_name, "model_name": model_name, "topic_id": i, "user_prompt": user_prompt, "response": response, "human_eval":human_eval, "run": run}
						json.dump(out, outfile)
						outfile.write("\n")
						time.sleep(0.5)
					i += 1

# %%
stdf = sample_tdf

# %%
a = next(stdf.iterrows())

# %%
system_prompt_NYT = """
You are a helpful assistant evaluating the top words of a topic model output for a given topic. 
Please rate how related the following words are to each other on a scale from 1 to 3 ("1" = not very related, "2" = moderately related, "3" = very related). 
The topic modeling is based on The New York Times corpus. The corpus consists of articles from 1987 to 2007. Sections from a typical paper include International, National, New York Regional, Business, Technology, and Sports news; features on topics such as Dining, Movies, Travel, and Fashion; there are also obituaries and opinion pieces.
Reply with a single number, indicating the overall appropriateness of the topic.
"""

# %%
# result = openai.ChatCompletion.create(
#     model="gpt-3.5-turbo", 
#     messages = [{"role": "system", "content": system_prompt}, {"role": "user", "content": user_prompt}], 
#     temperature=1.0, 
#     logit_bias={16:100, 17:100, 18:100}, max_tokens=1
# )

# result["choices"][0]["message"]["content"].strip()

# %%
from openai import OpenAI

system_prompt = """
You are a helpful assistant evaluating the top words of a topic model output for a given topic. 
Please rate how related the following words are to each other on a scale from 1 to 3 ("1" = not very related, "2" = moderately related, "3" = very related). 
Reply with a single number, indicating the overall appropriateness of the topic.
"""

client = OpenAI(
    # This is the default and can be omitted
    api_key="",
)

# %%
system_prompt = """
You are a helpful assistant evaluating the top words of a topic model output for a given topic. 
Please rate how related the following words are to each other on a scale from 1 to 4 ("1" = poorly related, "2" = rather poorly related, "3" = rather related, "4" = very related). 
Reply with a single number, indicating the overall appropriateness of the topic.
"""

# %%
topic = stdf.iloc[0]['INPUT:wordset']

# %%
topic
# Out:
# 'price board shipping package slot hello port sony thank unit sell purchase digital mask nubus'

# %%
stdf.shape
# Out:
# (60, 10)

# %%
def evaluate_llm(topic):
    user_prompt = ", ".join(topic)

    arr = []
    for i in range(5):
        chat_completion = client.chat.completions.create(
            model="gpt-4o",
            messages = [{"role": "system", "content": system_prompt}, {"role": "user", "content": user_prompt}],
            temperature=1.0,
            max_tokens=1
        )
        arr.append(chat_completion)

    return arr 

def num2score(num):
    # return 1 if num > 2 else 0
    return num

def get_metric(arr_chat_completion):
    nums = []
    for chat_completion in arr_chat_completion:
        try:
            s = chat_completion.choices[0].message.content.strip()
            num = int(s)
        except ValueError:
            warnings.warn(f"Bad number: {s}")
        nums.append(num)
    # nums = [ for chat_completion in arr_chat_completion]
    return mean(nums) 
    # return num2score(num)

def get_human_metric(x):
    name2score = {
        'good': 4,
        'rather_good': 3,
        'rather_bad': 2,
        'bad': 1
    }
    num = name2score[x]
    return num2score(num)

# %%
full_tdf = tdf[(tdf['INPUT:topic_id'] != 'unknown') & (~tdf['OUTPUT:quality'].isna())]
full_tdf['human_metric'] = full_tdf['OUTPUT:quality'].apply(get_human_metric)
full_tdf = full_tdf.groupby(['INPUT:model_id','INPUT:topic_id']).agg(
    human_metric=('human_metric', 'mean'),
    input_wordset=('INPUT:wordset', 'first'),
    dataset_name=('INPUT:dataset_name', 'first')
)
full_tdf = full_tdf.rename(columns={'input_wordset': 'INPUT:wordset', 'dataset_name': 'INPUT:dataset_name'}).reset_index()
# Out:
# /tmp/ipykernel_16742/180384493.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_tdf['human_metric'] = full_tdf['OUTPUT:quality'].apply(get_human_metric)

# %%
full_tdf.groupby(['INPUT:dataset_name']).agg(model_counts=('INPUT:model_id', 'nunique'))
# Out:
#                     model_counts
# INPUT:dataset_name
# 20newsgroups                 100
# amazon_food                  100
# lenta_ru                     100

# %%
df = full_tdf[['INPUT:dataset_name', 'INPUT:model_id']].groupby('INPUT:dataset_name', group_keys=False).apply(lambda x: x.sample(min(len(x), 12)))

# %%
df.groupby(['INPUT:dataset_name']).agg(model_counts=('INPUT:model_id', 'nunique'))
# Out:
#                     model_counts
# INPUT:dataset_name
# 20newsgroups                  12
# amazon_food                   11
# lenta_ru                      10

# %%
stdf = full_tdf[full_tdf[['INPUT:dataset_name','INPUT:model_id']].agg(tuple,1).isin(df[['INPUT:dataset_name','INPUT:model_id']].agg(tuple,1))]

# %%
stdf.groupby(['INPUT:dataset_name']).agg(model_counts=('INPUT:model_id', 'nunique'))
# Out:
#                     model_counts
# INPUT:dataset_name
# 20newsgroups                  12
# amazon_food                   11
# lenta_ru                      10

# %%
stdf.groupby(['INPUT:dataset_name', 'INPUT:model_id']).agg(model_counts=('INPUT:topic_id', 'nunique'))
# Out:
#                                              model_counts
# INPUT:dataset_name INPUT:model_id
# 20newsgroups       631b887f174d83c12d0f1a8d            22
#                    631b8a349a4c0179fe9f987b            22
#                    631b8c83641d50abc7aa3cbb            10
#                    631b9050814e124a8fb05f40            22
#                    631b992927e1a64b30541a0c            28
#                    631ba1dba6fa8975eb579abd            22
#                    631ba4b8cda35d28419fe92f            27
#                    631ba8a5963148fe573f0fcb            28
#                    631bab18a79807f67e840776            28
#                    631bb21d963148fe573f184d            22
#                    631bb32332591f66b7e678c5            33
#                    631bb42132591f66b7e67ad2            33
# amazon_food        63230b74395a63a800f692d5            28
#                    63230dd043fb92a9d143af7f            33
#                    632311c9eef852a376dcaf74            33
#                    6323199f4ac2fcd506e4c5d6            17
#                    63231a98dca999f95522c8e4            17
#                    63231b2715ff0c23bc8b8255            17
#                    6325db66814e124a8fb0d331            28
#                    6325dd002b337b5d95012d3f            28
#                    63260ed179ac792348a85e87            17
#                    632610e7cc299eeaf78e0711            17
#                    632620474fecb0a9aa0a8534            22
# lenta_ru           631b8623441f56e4790a8078            22
#                    631b8646d5a4fe1912c3eb29            33
#                    631b869e7668936a8be4f75a            17
#                    631b87844bb36217238dc39a            33
#                    631b88853cf48bd97d2c272d            33
#                    631b88ec8f66b70aae934dcb            33
#                    631b8a4025d962cdec4bc1f0            28
#                    631b8e35a5a57837b841a9ab            22
#                    631b9158ad5963ae703be71e            28
#                    631b92506d9890a069a95158            17

# %%
stdf = stdf.groupby(['INPUT:dataset_name', 'INPUT:model_id'], group_keys=False).apply(lambda x: x.sample(frac=0.5))

# %%
stdf.groupby(['INPUT:dataset_name']).agg(model_counts=('INPUT:model_id', 'nunique'))
# Out:
#                     model_counts
# INPUT:dataset_name
# 20newsgroups                  12
# amazon_food                   11
# lenta_ru                      10

# %%
stdf.groupby(['INPUT:dataset_name', 'INPUT:model_id']).agg(model_counts=('INPUT:topic_id', 'nunique'))
# Out:
#                                              model_counts
# INPUT:dataset_name INPUT:model_id
# 20newsgroups       631b887f174d83c12d0f1a8d            11
#                    631b8a349a4c0179fe9f987b            11
#                    631b8c83641d50abc7aa3cbb             5
#                    631b9050814e124a8fb05f40            11
#                    631b992927e1a64b30541a0c            14
#                    631ba1dba6fa8975eb579abd            11
#                    631ba4b8cda35d28419fe92f            14
#                    631ba8a5963148fe573f0fcb            14
#                    631bab18a79807f67e840776            14
#                    631bb21d963148fe573f184d            11
#                    631bb32332591f66b7e678c5            16
#                    631bb42132591f66b7e67ad2            16
# amazon_food        63230b74395a63a800f692d5            14
#                    63230dd043fb92a9d143af7f            16
#                    632311c9eef852a376dcaf74            16
#                    6323199f4ac2fcd506e4c5d6             8
#                    63231a98dca999f95522c8e4             8
#                    63231b2715ff0c23bc8b8255             8
#                    6325db66814e124a8fb0d331            14
#                    6325dd002b337b5d95012d3f            14
#                    63260ed179ac792348a85e87             8
#                    632610e7cc299eeaf78e0711             8
#                    632620474fecb0a9aa0a8534            11
# lenta_ru           631b8623441f56e4790a8078            11
#                    631b8646d5a4fe1912c3eb29            16
#                    631b869e7668936a8be4f75a             8
#                    631b87844bb36217238dc39a            16
#                    631b88853cf48bd97d2c272d            16
#                    631b88ec8f66b70aae934dcb            16
#                    631b8a4025d962cdec4bc1f0            14
#                    631b8e35a5a57837b841a9ab            11
#                    631b9158ad5963ae703be71e            14
#                    631b92506d9890a069a95158             8

# %%
stdf
# Out:
#                 INPUT:model_id INPUT:topic_id  human_metric  \
# 1114  631b887f174d83c12d0f1a8d          main3           2.4
# 1106  631b887f174d83c12d0f1a8d         main16           2.2
# 1108  631b887f174d83c12d0f1a8d          main2           3.6
# 1118  631b887f174d83c12d0f1a8d         main36           3.4
# 1121  631b887f174d83c12d0f1a8d         main42           3.2
# ...                        ...            ...           ...
# 2335  631b92506d9890a069a95158         main21           3.4
# 2328  631b92506d9890a069a95158         main10           3.6
# 2336  631b92506d9890a069a95158         main22           2.4
# 2334  631b92506d9890a069a95158         main20           3.0
# 2331  631b92506d9890a069a95158         main15           2.6
#
#                                           INPUT:wordset INPUT:dataset_name
# 1114  land country care health drug disease money ha...       20newsgroups
# 1106  henry access appear toronto digex orbit captai...       20newsgroups
# 1108  player hockey season league goal leaf playoff ...       20newsgroups
# 1118  bike speed turn mile apple tire front simms fa...       20newsgroups
# 1121  center research nasa medical april health canc...       20newsgroups
# ...                                                 ...                ...
# 2335  комитет сборная чемпионат никакой федерация со...           lenta_ru
# 2328  средство сумма условие деньги финансовый разме...           lenta_ru
# 2336  версия поступать выпускать релиз русский мероп...           lenta_ru
# 2334  создавать интернет позволять возможность сеть ...           lenta_ru
# 2331  участник республика удаваться начинаться прове...           lenta_ru
#
# [403 rows x 5 columns]

# %%
stdf['llm_score'] = stdf['INPUT:wordset'].progress_apply(evaluate_llm)
# Out:
# 100%|██████████| 403/403 [19:17<00:00,  2.87s/it]

# %%
# stdf.to_csv("big_sample_4class_avg.csv")

# %%
stdf['llm_metric'] = stdf['llm_score'].apply(get_metric)
# stdf['human_metric'] = stdf['OUTPUT:quality'].apply(get_human_metric)
# Out:
# /tmp/ipykernel_16742/460180858.py:27: UserWarning: Bad number: This
#   warnings.warn(f"Bad number: {s}")
# /tmp/ipykernel_16742/460180858.py:27: UserWarning: Bad number: Based
#   warnings.warn(f"Bad number: {s}")

# %%
stdf.columns
# Out:
# Index(['INPUT:model_id', 'INPUT:topic_id', 'human_metric', 'INPUT:wordset',
#        'INPUT:dataset_name', 'llm_score', 'llm_metric'],
#       dtype='object')

# %%
# fstdf = tdf[tdf[['INPUT:model_id','INPUT:topic_id']].agg(tuple,1).isin(stdf[['INPUT:model_id','INPUT:topic_id']].agg(tuple,1))]
# fstdf = fstdf[(fstdf['INPUT:topic_id'] != 'unknown') & (~fstdf['OUTPUT:quality'].isna())]
# fstdf['human_metric'] = fstdf['OUTPUT:quality'].apply(get_human_metric)
# fstdf = fstdf.groupby(['INPUT:model_id','INPUT:topic_id']).agg(human_metric=('human_metric', 'mean'))

# %%
# astdf = stdf.join(fstdf, on=['INPUT:model_id','INPUT:topic_id'], rsuffix='_right')
# astdf = astdf.drop(columns=['human_metric'])
# astdf = astdf.rename(columns={'human_metric_right': 'human_metric'})

# %%
df = stdf
# df = astdf

# %%
# df.groupby('OUTPUT:quality').agg({'llm_metric': 'mean'})

# %%
# df.boxplot(column=['llm_metric'], by='OUTPUT:quality')

# %%
df['INPUT:dataset_name'].unique()
# Out:
# array(['20newsgroups', 'amazon_food', 'lenta_ru'], dtype=object)

# %%
df[['human_metric', 'llm_metric']].corr()
# Out:
#               human_metric  llm_metric
# human_metric      1.000000    0.737239
# llm_metric        0.737239    1.000000

# %%
for ds_name in df['INPUT:dataset_name'].unique():
    print(f"======= {ds_name} =======")
    print(df[df['INPUT:dataset_name'] == ds_name][['human_metric', 'llm_metric']].corr())
# Out:
# ======= 20newsgroups =======
#               human_metric  llm_metric
# human_metric       1.00000     0.78557
# llm_metric         0.78557     1.00000
# ======= amazon_food =======
#               human_metric  llm_metric
# human_metric      1.000000    0.657408
# llm_metric        0.657408    1.000000
# ======= lenta_ru =======
#               human_metric  llm_metric
# human_metric      1.000000    0.644662
# llm_metric        0.644662    1.000000
